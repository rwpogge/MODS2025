# %% [markdown]
# # LBT IIF Header Definition File YAML Sandbox
#
# Sandbox notebook to develop using YAML for MODS2025
#
# Applications:
#  * runtime configuration files
#  * header configuration files
#
# YAML (YAML Ain't Markup Language) is a simple, structured, ascii-based data serialization language used
# across many  languages and operating systems that is often used for human-readable and editable runtime
# configuration files because of its simple syntax.
#
# ### Sources
#
#  * Official YAML website: https://yaml.org/
#  * PyYAML, the standard python YAML loader/emitter (comes with Anaconda): http://pyyaml.org
#  * A nice YAML tutorial: https://www.cloudbees.com/blog/yaml-tutorial-everything-you-need-get-started
#  * Another YAML tutorial: https://python.land/data-processing/python-yaml

# %%
import os
import math

# YAML module

import yaml

# %% [markdown]
# ## Load and parse a YAML file
#
# ### loadYAML() function
#
# We use the yaml `safe_load()` method instead of the deprecated `load()` method.

# %%
def loadYAML(fileName):
    """
    Load the contents of a YAML-format file using safe_load()
    """
    
    if os.path.exists(fileName):

        try:
            stream = open(fileName,'r')
        except Exception as exp:
            raise RuntimeError(f"ERROR: could not open {fileName}: {exp}")
            
        try:
            data = yaml.safe_load(stream)
        except yaml.YAMLError as exp:
            stream.close()
            raise RuntimeError(f"ERROR: could not load {fileName}: {exp}")
        
        if len(data)==0:
            raise RuntimeError(f"YAML file {fileName} is empty!")

        stream.close()
        return data
        
    else:
        raise ValueError(f"YAML file {fileName} does not exist")

# %% [markdown]
# ### read and print out
#
# Note that pyYAML strips out all comments (block and inline), so this is a formatted printout of the
# file contents without the comments.

# %%
myFile = "modsTCS_left_yaml.txt"

try:
    cfgData = loadYAML(myFile)
    print(f"\nRead YAML file {myFile}, contents:")
    for key in cfgData:
        print(f"\n{key}:")
        yamlItem = cfgData[key]
        for keyword in yamlItem:
            print(f"  {keyword}: {yamlItem[keyword]}")
except Exception as exp:
    print(f"ERROR: loadYAML() - {exp}")
# Out:
# Read YAML file modsTCS_left_yaml.txt, contents:
#
# IIFConfig:
#   instID: mods
#   side: left
#   client_config: /home/dts/Config/IIF/pySim.client
#
# DDEntries:
#   L_AchievedRAHMS: ['TELRA', 'str', 'SX Telescope Achieved RA [hms]']
#   L_AchievedDECDMS: ['TELDEC', 'str', 'SX Telescope Achieved DEC [dms]']
#   L_PosAngle: ['POSANGLE', 'float-rad', 'SX Instrument Celestial PA [deg]']
#   MountAchievedALTDMS: ['TELALT', 'str', 'Telescope Altitude at start of obs [dms]']
#   MountAchievedAZDMS: ['TELAZ', 'str', 'Telescope Azimuth at start of obs [dms]']
#   MountAchievedHAHMS: ['HA', 'str', 'Telescope Hour Angle at start of obs [hms]']
#   AirMass: ['AIRMASS', 'float', 'Airmass (secZD) at start of obs']
#   ParAngle: ['PARANGLE', 'float', 'Parallactic Angle at start of obs [deg]']
#   L_RotAngle: ['ROTANGLE', 'float-rad', 'SX Rotator Angle at start of obs [deg]']
#   L_RotMode: ['ROTMODE', 'str', 'SX Rotator Mode']
#   L_DGRPosition: ['DGROTPOS', 'float-as', 'SX Direct Gregorian Rotator Angle [deg]']
#   L_AGWKFPReqX: ['GPREQ_X', 'float', 'GCS Requested guide probe PCS X [mm]']
#   L_AGWKFPReqY: ['GPREQ_Y', 'float', 'GCS Requested guide probe PCS Y [mm]']
#   L_AGWKFPPosX: ['GPACT_X', 'float', 'GCS Actual guide probe PCS X [mm]']
#   L_AGWKFPPosY: ['GPACT_Y', 'float', 'GCS Actual guide probe PCX Y [mm]']
#   L_GSXPredicted: ['GSPRED_X', 'float', 'PCS Predicted guide star X position [mm]']
#   L_GSYPredicted: ['GSPRED_Y', 'float', 'PCS Predicted guide star Y position [mm]']
#   L_GSXMeasured: ['GSMEAS_X', 'float', 'GCS Measured guide star X position [mm]']
#   L_GSYMeasured: ['GSMEAS_Y', 'float', 'GCS Measured guide star Y position [mm]']
#   L_GSCumXPredmMeas: ['GSDELTAX', 'float', 'GCS cumulative X guide update position [mm]']
#   L_GSCumYPredmMeas: ['GSDELTAY', 'float', 'GCS cumulative Y guide update position [mm]']
#   L_M1CollX: ['M1POSX', 'float', 'Primary Mirror X Position [mm]']
#   L_M1CollY: ['M1POSY', 'float', 'Primary Mirror Y Position [mm]']
#   L_M1CollZ: ['M1POSZ', 'float', 'Primary Mirror Z Position [mm]']
#   L_M1CollRx: ['M1ROTX', 'float', 'Primary Mirror RX Rotation [arcsec]']
#   L_M1CollRy: ['M1ROTY', 'float', 'Primary Mirror RY Rotation [arcsec]']
#   L_M1CollRz: ['M1ROTZ', 'float', 'Primary Mirror RZ Rotation [arcsec]']
#   L_M1CollTemp: ['M1CTEMP', 'float', 'Primary Mirror Temperature [deg C]']
#   L_M1CollTemp2: ['M1CTEMP2', 'float', 'Primary Mirror Temperature 2 [deg C]']
#   L_M1AirTemp: ['M1GTEMP', 'float', 'Primary Mirror Glass Temperature [deg C]']
#   L_M1GlassTemp: ['M1ATEMP', 'float', 'Primary Mirror Ambient Air Temp [deg C]']
#   L_M2CollX: ['M2POSX', 'float', 'Secondary Mirror X Position [mm]']
#   L_M2CollY: ['M2POSY', 'float', 'Secondary Mirror Y Position [mm]']
#   L_M2CollZ: ['M2POSZ', 'float', 'Secondary Mirror Z Position [mm]']
#   L_M2CollRx: ['M2ROTX', 'float', 'Secondary Mirror RX Rotation [arcsec]']
#   L_M2CollRy: ['M2ROTY', 'float', 'Secondary Mirror RY Rotation [arcsec]']
#   L_M2CollRz: ['M2ROTZ', 'float', 'Secondary Mirror RZ Rotation [arcsec]']
#   L_M2CollTemp: ['M2CTEMP', 'float', 'Secondary Mirror Temperature [deg C]']
#   Temp201: ['TTEMP201', 'float', 'Middle C-Ring Steel Temp [deg C]']
#   Temp202: ['TTEMP202', 'float', 'Middle C-Ring Air Temp [deg C]']
#   Temp203: ['TTEMP203', 'float', 'Upper C-Ring Steel Temp [deg C]']
#   Temp204: ['TTEMP204', 'float', 'Upper C-Ring Air Temp [deg C]']
#   Temp205: ['TTEMP205', 'float', 'Lower C-Ring Steel Temp [deg C]']
#   Temp206: ['TTEMP206', 'float', 'Lower C-Ring Air Temp [deg C]']
#   Temp207: ['TTEMP207', 'float', 'Right Lower Wind Brace Steel Temp [deg C]']
#   Temp208: ['TTEMP208', 'float', 'Right Lower Wind Brace Air Temp [deg C]']
#   Temp209: ['TTEMP209', 'float', 'Right Mirror-Cell Brace Steel Temp [deg C]']
#   Temp210: ['TTEMP210', 'float', 'Right Mirror-Cell Brace Air Temp [deg C]']
#   Temp301: ['TTEMP301', 'float', 'Right C-Ring Extension Steel Temp [deg C]']
#   Temp302: ['TTEMP302', 'float', 'Right C-Ring Extension Air Temp [deg C]']
#   Temp303: ['TTEMP303', 'float', 'Left C-Ring Extension Steel Temp [deg C]']
#   Temp304: ['TTEMP304', 'float', 'Left C-Ring Extension Air Temp [deg C]']
#   Temp305: ['TTEMP305', 'float', 'Upper Wind Brace Steel Temp [deg C]']
#   Temp306: ['TTEMP306', 'float', 'Upper Wind Brace Air Temp [deg C]']
#   Temp307: ['TTEMP307', 'float', 'Right Middle Wind Brace Steel Temp [deg C]']
#   Temp308: ['TTEMP308', 'float', 'Right Middle Wind Brace Air Temp [deg C]']
#   Temp309: ['TTEMP309', 'float', 'Left Middle Wind Brace Steel Temp [deg C]']
#   Temp310: ['TTEMP310', 'float', 'Left Middle Wind Brace Air Temp [deg C]']
#   Temp401: ['TTEMP401', 'float', 'Right primary Swing Arm Steel Temp1 [deg C]']
#   Temp402: ['TTEMP402', 'float', 'Right primary Swing Arm Steel Temp2 [deg C]']
#   Temp403: ['TTEMP403', 'float', 'Left primary Swing Arm Steel Temp1 [deg C]']
#   Temp404: ['TTEMP404', 'float', 'Left primary Swing Arm Steel Temp2 [deg C]']
#   Temp405: ['TTEMP405', 'float', 'Right secondary Swing Arm Steel Temp1 [deg C]']
#   Temp406: ['TTEMP406', 'float', 'Right secondary Swing Arm Steel Temp2 [deg C]']
#   Temp407: ['TTEMP407', 'float', 'Left secondary Swing Arm Steel Temp1 [deg C]']
#   Temp408: ['TTEMP408', 'float', 'Left secondary Swing Arm Steel Temp2 [deg C]']
#   LBTWeatherAlive: ['LBTWLINK', 'string', 'LBT Weather Station Link State']
#   LBTPressure: ['LBTPRES', 'float', 'LBT Ambient Pressure [hPa]']
#   LBTTemp: ['LBTTEMP', 'float', 'LBT Ambient Temperature [deg C]']
#   LBTHumidity: ['LBTHUM', 'float', 'LBT Relative Humidity [percent]']
#   LBTDewPoint: ['LBTDWPT', 'float', 'LBT Dew Point [deg C]']

# %% [markdown]
# ### tcsData
#
# a sample TCS data stream from the TCS simulator for the list of DD entries above.

# %%
tcsData = ['20:44:38.267',
           '+57:09:34.34',
           '0.000000000000000e+00',
           '+00:00:00.00',
           '+00:00:00.000',
           '-11:58:39.317',
           '1.337481353441951e+01',
           '-2.828959739227836e-01',
           '-1.149379660918177e+00',
           '',
           '0.0000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '0.000000000000000e+00',
           '6.4275622e-01',
           '2.9556349e-01',
           '-6.1020829e-02',
           '1.7784439e+01',
           '-4.1758141e+01',
           '-1.8206030e-02',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '-3.0005002e+00',
           '-3.3000002e+00',
           '7.6899999e-01',
           '2.7304501e+02',
           '-4.4506500e+01',
           '-1.7423400e-01',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00',
           '0.0000000e+00']

# %% [markdown]
# ## Process
#
# Turn into commands for the data-taking system

# %%
dataKey = 'DDEntries'

# extract the DD dictionary and list of DD entries (ddList)

ddDict = cfgData[dataKey]
ddList = list(ddDict.keys())

# build the dictionaries that FITS keywords to IIF DD entries and their attributes: 
#   fitsList = list of FITS header keywords
#   iifKeywords = dictionary of IIF DD entries corresponding to fitsList
#   iifTypes = dictionary of typestrings corresponding to IIF DD data (removing float type units conversion tags)
#   iifComments = dictionary of comments corresponding to IIF DD data

fitsList = []
iifKeywords = {}
iifComments = {}
iifTypes = {}
for key in ddList:
    fitsKey = ddDict[key][0].upper() # enforce uppercase for FITS keywords
    fitsList.append(fitsKey)
    iifKeywords[fitsKey] = key
    if ddDict[key][1].startswith("float"):
        iifTypes[fitsKey] = "float"
    else:
        iifTypes[fitsKey] = ddDict[key][1]
    iifComments[fitsKey] = ddDict[key][2]

# Get the instrument parameters for the IIF client

instID = cfgData["IIFConfig"]["instID"]
side = cfgData["IIFConfig"]["side"]
cfgFile = cfgData["IIFConfig"]["client_config"]

# proxy name for the IIF instance

proxyName = f"py_{instID}_{side}"
print("\nVariables to pass to python-iif methods built from IIFConfig data:\n")

print(f"  proxyName = {proxyName}")
print(f"  side = {side}")
print(f"  config_client = {cfgFile}")

# generate code
print("\npython-iif code:\n")
print("  import lbto.iif as iif\n")
print(f"  proxy = iif.model['Proxies'].get({instID})")
print(f"  tcs = iif.iifproxy(proxyName=proxyName,instrument=proxy['instrument'],")
print("                     focalStation=proxy['focalstation'],side=side,")
print(f"                     config_client=cfgFile)")
print(f"\n  tcsData = tcs.GetParameter(ddList)")

# process tcsData (actual stream in cell above)

print(f"\nPython code to set the keyword in the Telescope::read_header() method:\n")

header = []

for i, ddKey in enumerate(ddList):
    key = fitsList[i]
    c = iifComments[key]
    t = iifTypes[key]
    iift = ddDict[ddKey][1]
    if iift == 'str':
        v = tcsData[i]
    elif iift == 'int':
        t = 'int'
        v = int(tcsData[i])
    elif iift == 'float':
        t = 'float'
        v = float(tcsData[i])
    elif iift == 'float-as':
        t = 'float'
        v = float(tcsData[i])/3600.0
    elif iift == 'float-rad':
        t = 'float'
        v = math.degrees(float(tcsData[i]))
    else:
        t = 'str'
        v = tcsData[i]
    header.append([key,v,c,t])
    print(f"  self.header.set_keyword({key},{v},{c},{t})")

print("\nheader list returned by Telescope::read_header() method:\n")
print(header)
# Out:
# Variables to pass to python-iif methods built from IIFConfig data:
#
#   proxyName = py_mods_left
#   side = left
#   config_client = /home/dts/Config/IIF/pySim.client
#
# python-iif code:
#
#   import lbto.iif as iif
#
#   proxy = iif.model['Proxies'].get(mods)
#   tcs = iif.iifproxy(proxyName=proxyName,instrument=proxy['instrument'],
#                      focalStation=proxy['focalstation'],side=side,
#                      config_client=cfgFile)
#
#   tcsData = tcs.GetParameter(ddList)
#
# Python code to set the keyword in the Telescope::read_header() method:
#
#   self.header.set_keyword(TELRA,20:44:38.267,SX Telescope Achieved RA [hms],str)
#   self.header.set_keyword(TELDEC,+57:09:34.34,SX Telescope Achieved DEC [dms],str)
#   self.header.set_keyword(POSANGLE,0.0,SX Instrument Celestial PA [deg],float)
#   self.header.set_keyword(TELALT,+00:00:00.00,Telescope Altitude at start of obs [dms],str)
#   self.header.set_keyword(TELAZ,+00:00:00.000,Telescope Azimuth at start of obs [dms],str)
#   self.header.set_keyword(HA,-11:58:39.317,Telescope Hour Angle at start of obs [hms],str)
#   self.header.set_keyword(AIRMASS,13.37481353441951,Airmass (secZD) at start of obs,float)
#   self.header.set_keyword(PARANGLE,-0.2828959739227836,Parallactic Angle at start of obs [deg],float)
#   self.header.set_keyword(ROTANGLE,-65.85460362878919,SX Rotator Angle at start of obs [deg],float)
#   self.header.set_keyword(ROTMODE,,SX Rotator Mode,str)
#   self.header.set_keyword(DGROTPOS,0.0,SX Direct Gregorian Rotator Angle [deg],float)
#   self.header.set_keyword(GPREQ_X,0.0,GCS Requested guide probe PCS X [mm],float)
#   self.header.set_keyword(GPREQ_Y,0.0,GCS Requested guide probe PCS Y [mm],float)
#   self.header.set_keyword(GPACT_X,0.0,GCS Actual guide probe PCS X [mm],float)
#   self.header.set_keyword(GPACT_Y,0.0,GCS Actual guide probe PCX Y [mm],float)
#   self.header.set_keyword(GSPRED_X,0.0,PCS Predicted guide star X position [mm],float)
#   self.header.set_keyword(GSPRED_Y,0.0,PCS Predicted guide star Y position [mm],float)
#   self.header.set_keyword(GSMEAS_X,0.0,GCS Measured guide star X position [mm],float)
#   self.header.set_keyword(GSMEAS_Y,0.0,GCS Measured guide star Y position [mm],float)
#   self.header.set_keyword(GSDELTAX,0.0,GCS cumulative X guide update position [mm],float)
#   self.header.set_keyword(GSDELTAY,0.0,GCS cumulative Y guide update position [mm],float)
#   self.header.set_keyword(M1POSX,0.64275622,Primary Mirror X Position [mm],float)
#   self.header.set_keyword(M1POSY,0.29556349,Primary Mirror Y Position [mm],float)
#   self.header.set_keyword(M1POSZ,-0.061020829,Primary Mirror Z Position [mm],float)
#   self.header.set_keyword(M1ROTX,17.784439,Primary Mirror RX Rotation [arcsec],float)
#   self.header.set_keyword(M1ROTY,-41.758141,Primary Mirror RY Rotation [arcsec],float)
#   self.header.set_keyword(M1ROTZ,-0.01820603,Primary Mirror RZ Rotation [arcsec],float)
#   self.header.set_keyword(M1CTEMP,0.0,Primary Mirror Temperature [deg C],float)
#   self.header.set_keyword(M1CTEMP2,0.0,Primary Mirror Temperature 2 [deg C],float)
#   self.header.set_keyword(M1GTEMP,0.0,Primary Mirror Glass Temperature [deg C],float)
#   self.header.set_keyword(M1ATEMP,0.0,Primary Mirror Ambient Air Temp [deg C],float)
#   self.header.set_keyword(M2POSX,-3.0005002,Secondary Mirror X Position [mm],float)
#   self.header.set_keyword(M2POSY,-3.3000002,Secondary Mirror Y Position [mm],float)
#   self.header.set_keyword(M2POSZ,0.76899999,Secondary Mirror Z Position [mm],float)
#   self.header.set_keyword(M2ROTX,273.04501,Secondary Mirror RX Rotation [arcsec],float)
#   self.header.set_keyword(M2ROTY,-44.5065,Secondary Mirror RY Rotation [arcsec],float)
#   self.header.set_keyword(M2ROTZ,-0.174234,Secondary Mirror RZ Rotation [arcsec],float)
#   self.header.set_keyword(M2CTEMP,0.0,Secondary Mirror Temperature [deg C],float)
#   self.header.set_keyword(TTEMP201,0.0,Middle C-Ring Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP202,0.0,Middle C-Ring Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP203,0.0,Upper C-Ring Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP204,0.0,Upper C-Ring Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP205,0.0,Lower C-Ring Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP206,0.0,Lower C-Ring Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP207,0.0,Right Lower Wind Brace Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP208,0.0,Right Lower Wind Brace Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP209,0.0,Right Mirror-Cell Brace Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP210,0.0,Right Mirror-Cell Brace Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP301,0.0,Right C-Ring Extension Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP302,0.0,Right C-Ring Extension Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP303,0.0,Left C-Ring Extension Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP304,0.0,Left C-Ring Extension Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP305,0.0,Upper Wind Brace Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP306,0.0,Upper Wind Brace Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP307,0.0,Right Middle Wind Brace Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP308,0.0,Right Middle Wind Brace Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP309,0.0,Left Middle Wind Brace Steel Temp [deg C],float)
#   self.header.set_keyword(TTEMP310,0.0,Left Middle Wind Brace Air Temp [deg C],float)
#   self.header.set_keyword(TTEMP401,0.0,Right primary Swing Arm Steel Temp1 [deg C],float)
#   self.header.set_keyword(TTEMP402,0.0,Right primary Swing Arm Steel Temp2 [deg C],float)
#   self.header.set_keyword(TTEMP403,0.0,Left primary Swing Arm Steel Temp1 [deg C],float)
#   self.header.set_keyword(TTEMP404,0.0,Left primary Swing Arm Steel Temp2 [deg C],float)
#   self.header.set_keyword(TTEMP405,0.0,Right secondary Swing Arm Steel Temp1 [deg C],float)
#   self.header.set_keyword(TTEMP406,0.0,Right secondary Swing Arm Steel Temp2 [deg C],float)
#   self.header.set_keyword(TTEMP407,0.0,Left secondary Swing Arm Steel Temp1 [deg C],float)
#   self.header.set_keyword(TTEMP408,0.0,Left secondary Swing Arm Steel Temp2 [deg C],float)
#   self.header.set_keyword(LBTWLINK,0,LBT Weather Station Link State,str)
#   self.header.set_keyword(LBTPRES,0.0,LBT Ambient Pressure [hPa],float)
#   self.header.set_keyword(LBTTEMP,0.0,LBT Ambient Temperature [deg C],float)
#   self.header.set_keyword(LBTHUM,0.0,LBT Relative Humidity [percent],float)
#   self.header.set_keyword(LBTDWPT,0.0,LBT Dew Point [deg C],float)
#
# header list returned by Telescope::read_header() method:
#
# [['TELRA', '20:44:38.267', 'SX Telescope Achieved RA [hms]', 'str'], ['TELDEC', '+57:09:34.34', 'SX Telescope Achieved DEC [dms]', 'str'], ['POSANGLE', 0.0, 'SX Instrument Celestial PA [deg]', 'float'], ['TELALT', '+00:00:00.00', 'Telescope Altitude at start of obs [dms]', 'str'], ['TELAZ', '+00:00:00.000', 'Telescope Azimuth at start of obs [dms]', 'str'], ['HA', '-11:58:39.317', 'Telescope Hour Angle at start of obs [hms]', 'str'], ['AIRMASS', 13.37481353441951, 'Airmass (secZD) at start of obs', 'float'], ['PARANGLE', -0.2828959739227836, 'Parallactic Angle at start of obs [deg]', 'float'], ['ROTANGLE', -65.85460362878919, 'SX Rotator Angle at start of obs [deg]', 'float'], ['ROTMODE', '', 'SX Rotator Mode', 'str'], ['DGROTPOS', 0.0, 'SX Direct Gregorian Rotator Angle [deg]', 'float'], ['GPREQ_X', 0.0, 'GCS Requested guide probe PCS X [mm]', 'float'], ['GPREQ_Y', 0.0, 'GCS Requested guide probe PCS Y [mm]', 'float'], ['GPACT_X', 0.0, 'GCS Actual guide probe PCS X [mm]', 'float'], ['GPACT_Y', 0.0, 'GCS Actual guide probe PCX Y [mm]', 'float'], ['GSPRED_X', 0.0, 'PCS Predicted guide star X position [mm]', 'float'], ['GSPRED_Y', 0.0, 'PCS Predicted guide star Y position [mm]', 'float'], ['GSMEAS_X', 0.0, 'GCS Measured guide star X position [mm]', 'float'], ['GSMEAS_Y', 0.0, 'GCS Measured guide star Y position [mm]', 'float'], ['GSDELTAX', 0.0, 'GCS cumulative X guide update position [mm]', 'float'], ['GSDELTAY', 0.0, 'GCS cumulative Y guide update position [mm]', 'float'], ['M1POSX', 0.64275622, 'Primary Mirror X Position [mm]', 'float'], ['M1POSY', 0.29556349, 'Primary Mirror Y Position [mm]', 'float'], ['M1POSZ', -0.061020829, 'Primary Mirror Z Position [mm]', 'float'], ['M1ROTX', 17.784439, 'Primary Mirror RX Rotation [arcsec]', 'float'], ['M1ROTY', -41.758141, 'Primary Mirror RY Rotation [arcsec]', 'float'], ['M1ROTZ', -0.01820603, 'Primary Mirror RZ Rotation [arcsec]', 'float'], ['M1CTEMP', 0.0, 'Primary Mirror Temperature [deg C]', 'float'], ['M1CTEMP2', 0.0, 'Primary Mirror Temperature 2 [deg C]', 'float'], ['M1GTEMP', 0.0, 'Primary Mirror Glass Temperature [deg C]', 'float'], ['M1ATEMP', 0.0, 'Primary Mirror Ambient Air Temp [deg C]', 'float'], ['M2POSX', -3.0005002, 'Secondary Mirror X Position [mm]', 'float'], ['M2POSY', -3.3000002, 'Secondary Mirror Y Position [mm]', 'float'], ['M2POSZ', 0.76899999, 'Secondary Mirror Z Position [mm]', 'float'], ['M2ROTX', 273.04501, 'Secondary Mirror RX Rotation [arcsec]', 'float'], ['M2ROTY', -44.5065, 'Secondary Mirror RY Rotation [arcsec]', 'float'], ['M2ROTZ', -0.174234, 'Secondary Mirror RZ Rotation [arcsec]', 'float'], ['M2CTEMP', 0.0, 'Secondary Mirror Temperature [deg C]', 'float'], ['TTEMP201', 0.0, 'Middle C-Ring Steel Temp [deg C]', 'float'], ['TTEMP202', 0.0, 'Middle C-Ring Air Temp [deg C]', 'float'], ['TTEMP203', 0.0, 'Upper C-Ring Steel Temp [deg C]', 'float'], ['TTEMP204', 0.0, 'Upper C-Ring Air Temp [deg C]', 'float'], ['TTEMP205', 0.0, 'Lower C-Ring Steel Temp [deg C]', 'float'], ['TTEMP206', 0.0, 'Lower C-Ring Air Temp [deg C]', 'float'], ['TTEMP207', 0.0, 'Right Lower Wind Brace Steel Temp [deg C]', 'float'], ['TTEMP208', 0.0, 'Right Lower Wind Brace Air Temp [deg C]', 'float'], ['TTEMP209', 0.0, 'Right Mirror-Cell Brace Steel Temp [deg C]', 'float'], ['TTEMP210', 0.0, 'Right Mirror-Cell Brace Air Temp [deg C]', 'float'], ['TTEMP301', 0.0, 'Right C-Ring Extension Steel Temp [deg C]', 'float'], ['TTEMP302', 0.0, 'Right C-Ring Extension Air Temp [deg C]', 'float'], ['TTEMP303', 0.0, 'Left C-Ring Extension Steel Temp [deg C]', 'float'], ['TTEMP304', 0.0, 'Left C-Ring Extension Air Temp [deg C]', 'float'], ['TTEMP305', 0.0, 'Upper Wind Brace Steel Temp [deg C]', 'float'], ['TTEMP306', 0.0, 'Upper Wind Brace Air Temp [deg C]', 'float'], ['TTEMP307', 0.0, 'Right Middle Wind Brace Steel Temp [deg C]', 'float'], ['TTEMP308', 0.0, 'Right Middle Wind Brace Air Temp [deg C]', 'float'], ['TTEMP309', 0.0, 'Left Middle Wind Brace Steel Temp [deg C]', 'float'], ['TTEMP310', 0.0 ...
